# %% [markdown]
# # Lab Manual Task1 :
# 1:Install python jupyter notebook and install the nltk pandas
# 2:take a paragraph of 100 words or 200 words and words then remove the punctuation from
# the paragraph
# 2:Perform tokenization of the paragraph taken

# %% [markdown]
# #### Step:1 Requirement

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Muhammad
# [nltk_data]     Yahya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### Step:2 Collect Corpus

# %%
paragraph = """
Natural Language Processing (NLP) is a field of artificial intelligence 
that focuses on the interaction between computers and humans through natural language. 
The goal of NLP is to enable computers to understand, interpret, and generate human 
language in a valuable way. It involves various tasks such as text classification,
sentiment analysis, machine translation, and speech recognition. With the help of NLP, 
machines can process large amounts of text data efficiently. It plays a crucial role 
in applications like chatbots, search engines, and virtual assistants.

"""

# %% [markdown]
# #### Step:3 Punctuation Remove

# %%
import string
clean_text = paragraph.translate(str.maketrans('', '', string.punctuation))
print(f'Text Without Punctuation:\n{clean_text}')
# Out:
# Text Without Punctuation:
#
# Natural Language Processing NLP is a field of artificial intelligence
# that focuses on the interaction between computers and humans through natural language
# The goal of NLP is to enable computers to understand interpret and generate human
# language in a valuable way It involves various tasks such as text classification
# sentiment analysis machine translation and speech recognition With the help of NLP
# machines can process large amounts of text data efficiently It plays a crucial role
# in applications like chatbots search engines and virtual assistants

# %% [markdown]
# #### Step 4: Tokenization

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(clean_text)
print(tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', 'The', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'in', 'a', 'valuable', 'way', 'It', 'involves', 'various', 'tasks', 'such', 'as', 'text', 'classification', 'sentiment', 'analysis', 'machine', 'translation', 'and', 'speech', 'recognition', 'With', 'the', 'help', 'of', 'NLP', 'machines', 'can', 'process', 'large', 'amounts', 'of', 'text', 'data', 'efficiently', 'It', 'plays', 'a', 'crucial', 'role', 'in', 'applications', 'like', 'chatbots', 'search', 'engines', 'and', 'virtual', 'assistants']

# %%
len(tokens)
# Out:
# 84
