# %% [markdown]
# # Stemming

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
words = [
    "data", "science", "machine", "learning", "artificial", "intelligence",
    "python", "model", "training", "testing", "algorithm", "analysis",
    "feature", "engineering", "prediction", "classification", "regression",
    "dataset", "neural", "network", "deep", "learning", "nlp",
    "text", "processing", "language", "understanding", "tokenization",
    "stemming", "lemmatization", "embedding", "vector", "transformer",
    "attention", "sequence", "label", "accuracy", "loss", "optimization"
]

# %%
stemming = PorterStemmer()

for word in words:
    print(word+"----->"+stemming.stem(word))
# Out:
# data----->data
# science----->scienc
# machine----->machin
# learning----->learn
# artificial----->artifici
# intelligence----->intellig
# python----->python
# model----->model
# training----->train
# testing----->test
# algorithm----->algorithm
# analysis----->analysi
# feature----->featur
# engineering----->engin
# prediction----->predict
# classification----->classif
# regression----->regress
# dataset----->dataset
# neural----->neural
# network----->network
# deep----->deep
# learning----->learn
# nlp----->nlp
# text----->text
# processing----->process
# language----->languag
# understanding----->understand
# tokenization----->token
# stemming----->stem
# lemmatization----->lemmat
# embedding----->embed
# vector----->vector
# transformer----->transform
# attention----->attent
# sequence----->sequenc
# label----->label
# accuracy----->accuraci
# loss----->loss
# optimization----->optim

# %%
stemming.stem('I Love NLP')
# Out:
# 'i love nlp'

# %%
stemming.stem('Congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('MachineLearning')
# Out:
# 'machinelearn'

# %%
stemming.stem('Machine Learning')
# Out:
# 'machine learn'

# %% [markdown]
# # Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
word_net_lemmatizer = WordNetLemmatizer()

for word in words:
    print(f'{word}----->{word_net_lemmatizer.lemmatize(word)}')
# Out:
# data----->data
# science----->science
# machine----->machine
# learning----->learn
# artificial----->artificial
# intelligence----->intelligence
# python----->python
# model----->model
# training----->train
# testing----->test
# algorithm----->algorithm
# analysis----->analysis
# feature----->feature
# engineering----->engineer
# prediction----->prediction
# classification----->classification
# regression----->regression
# dataset----->dataset
# neural----->neural
# network----->network
# deep----->deep
# learning----->learn
# nlp----->nlp
# text----->text
# processing----->process
# language----->language
# understanding----->understand
# tokenization----->tokenization
# stemming----->stem
# lemmatization----->lemmatization
# embedding----->embed
# vector----->vector
# transformer----->transformer
# attention----->attention
# sequence----->sequence
# label----->label
# accuracy----->accuracy
# loss----->loss
# optimization----->optimization

# %%
'''
pos-Noun-n
verb-v
adjective-a
adverb-r
'''

for word in words:
    print(f'{word}----->{word_net_lemmatizer.lemmatize(word , pos='v')}')
# Out:
# data----->data
# science----->science
# machine----->machine
# learning----->learn
# artificial----->artificial
# intelligence----->intelligence
# python----->python
# model----->model
# training----->train
# testing----->test
# algorithm----->algorithm
# analysis----->analysis
# feature----->feature
# engineering----->engineer
# prediction----->prediction
# classification----->classification
# regression----->regression
# dataset----->dataset
# neural----->neural
# network----->network
# deep----->deep
# learning----->learn
# nlp----->nlp
# text----->text
# processing----->process
# language----->language
# understanding----->understand
# tokenization----->tokenization
# stemming----->stem
# lemmatization----->lemmatization
# embedding----->embed
# vector----->vector
# transformer----->transformer
# attention----->attention
# sequence----->sequence
# label----->label
# accuracy----->accuracy
# loss----->loss
# optimization----->optimization

# %%
# Use Case:Lemmatization & Stemming 

# Sentiment Analysis ----> Stemming
# Chatbot ----> Lemmatization

# %% [markdown]
# # Practice Time

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
words = [
    "data", "science", "machine", "learning", "artificial", "intelligence",
    "python", "model", "training", "testing", "algorithm", "analysis",
    "feature", "engineering", "prediction", "classification", "regression",
    "dataset", "neural", "network", "deep", "learning", "nlp",
    "text", "processing", "language", "understanding", "tokenization",
    "stemming", "lemmatization", "embedding", "vector", "transformer",
    "attention", "sequence", "label", "accuracy", "loss", "optimization"
]

# %%
len(words)
# Out:
# 39

# %%
for word in words:
    print(word +'---->'+ PorterStemmer().stem(word))
# Out:
# data---->data
# science---->scienc
# machine---->machin
# learning---->learn
# artificial---->artifici
# intelligence---->intellig
# python---->python
# model---->model
# training---->train
# testing---->test
# algorithm---->algorithm
# analysis---->analysi
# feature---->featur
# engineering---->engin
# prediction---->predict
# classification---->classif
# regression---->regress
# dataset---->dataset
# neural---->neural
# network---->network
# deep---->deep
# learning---->learn
# nlp---->nlp
# text---->text
# processing---->process
# language---->languag
# understanding---->understand
# tokenization---->token
# stemming---->stem
# lemmatization---->lemmat
# embedding---->embed
# vector---->vector
# transformer---->transform
# attention---->attent
# sequence---->sequenc
# label---->label
# accuracy---->accuraci
# loss---->loss
# optimization---->optim

# %%
PorterStemmer().stem('ArithmeticError')
# Out:
# 'arithmeticerror'

# %%
PorterStemmer().stem('BaseExceptionGroup')
# Out:
# 'baseexceptiongroup'

# %%
PorterStemmer().stem('Exception')
# Out:
# 'except'

# %%
for word in words:
    print(f'{word}---->{WordNetLemmatizer().lemmatize(word)}')
# Out:
# data---->data
# science---->science
# machine---->machine
# learning---->learning
# artificial---->artificial
# intelligence---->intelligence
# python---->python
# model---->model
# training---->training
# testing---->testing
# algorithm---->algorithm
# analysis---->analysis
# feature---->feature
# engineering---->engineering
# prediction---->prediction
# classification---->classification
# regression---->regression
# dataset---->dataset
# neural---->neural
# network---->network
# deep---->deep
# learning---->learning
# nlp---->nlp
# text---->text
# processing---->processing
# language---->language
# understanding---->understanding
# tokenization---->tokenization
# stemming---->stemming
# lemmatization---->lemmatization
# embedding---->embedding
# vector---->vector
# transformer---->transformer
# attention---->attention
# sequence---->sequence
# label---->label
# accuracy---->accuracy
# loss---->loss
# optimization---->optimization

# %%
for word in words:
    print(f'{word}---->{WordNetLemmatizer().lemmatize(word , pos='r')}')
# Out:
# data---->data
# science---->science
# machine---->machine
# learning---->learning
# artificial---->artificial
# intelligence---->intelligence
# python---->python
# model---->model
# training---->training
# testing---->testing
# algorithm---->algorithm
# analysis---->analysis
# feature---->feature
# engineering---->engineering
# prediction---->prediction
# classification---->classification
# regression---->regression
# dataset---->dataset
# neural---->neural
# network---->network
# deep---->deep
# learning---->learning
# nlp---->nlp
# text---->text
# processing---->processing
# language---->language
# understanding---->understanding
# tokenization---->tokenization
# stemming---->stemming
# lemmatization---->lemmatization
# embedding---->embedding
# vector---->vector
# transformer---->transformer
# attention---->attention
# sequence---->sequence
# label---->label
# accuracy---->accuracy
# loss---->loss
# optimization---->optimization
