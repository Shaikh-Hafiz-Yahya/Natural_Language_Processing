# %% [markdown]
# # Lowercasing

# %% [markdown]
# # Level 1: Basic Practice

# %% [markdown]
# ### Q:1 Convert this text into lowercase:

# %%
text = 'HELLO WORLD FROM NLP'
sentance1 = text

# %%
lower1 = sentance1.lower()
print(lower1)
# Out:
# hello world from nlp

# %% [markdown]
# ### Q:2 Python Is GREAT For Machine Learning

# %%
sentance2 = 'Python Is GREAT For Machine Learning'

lowercase2 = sentance2.lower()
print(lowercase2)
# Out:
# python is great for machine learning

# %% [markdown]
# ### Q:3 DATA SCIENCE AND AI

# %%
sentance3 = 'DATA SCIENCE AND AI'

lowercase3 = sentance3.lower()
print(lowercase3)
# Out:
# data science and ai

# %% [markdown]
# # Level 2: Sentences

# %% [markdown]
# ### Q4: This Is A Simple Sentence For Testing.

# %%
sentance4 = 'This Is A Simple Sentence For Testing.'

lowercase3 = sentance4.lower()
print(lowercase3)
# Out:
# this is a simple sentence for testing.

# %% [markdown]
# ### Q5: Natural Language Processing Is AMAZING!

# %%
sentance5 = 'Natural Language Processing Is AMAZING!'

lowercase5 = sentance5.lower()
print(lowercase5)
# Out:
# natural language processing is amazing!

# %% [markdown]
# ### Q6: I LOVE PYTHON, DO YOU?

# %%
sentance6 = 'I LOVE PYTHON, DO YOU?'

lowercase6 = sentance6.lower()
print(lowercase6)
# Out:
# i love python, do you?

# %% [markdown]
# # Level 3: Mixed Text (Important 🔥)

# %% [markdown]
# ### Q7: Visit GOOGLE.COM For More INFO

# %%
sentance7 = 'Visit GOOGLE.COM For More INFO'

lowercase7 = sentance7.lower()
print(lowercase7)
# Out:
# visit google.com for more info

# %% [markdown]
# ### Q8: HELLO User123, Welcome To NLP Class!

# %%
sentance8 = 'HELLO User123, Welcome To NLP Class!'

lowercase8 = sentance8.lower()
print(lowercase8)
# Out:
# hello user123, welcome to nlp class!

# %% [markdown]
# ### Q9: Machine Learning & Deep Learning Are FUTURE Technologies.

# %%
sentance9 = 'Machine Learning & Deep Learning Are FUTURE Technologies.'

lowercase9 = sentance9.lower()
print(lowercase9)
# Out:
# machine learning & deep learning are future technologies.

# %% [markdown]
# ### Level 4: Real NLP Style

# %% [markdown]
# ### Q10: <html>THIS IS HTML CONTENT</html>

# %%
sentance10 = '<html>THIS IS HTML CONTENT</html>'

lowercase10 = sentance10.lower()
print(lowercase10)
# Out:
# <html>this is html content</html>

# %% [markdown]
# ### Q11: Check This LINK: HTTPS://EXAMPLE.COM

# %%
sentance11 = 'Check This LINK: HTTPS://EXAMPLE.COM'

sentance11 = sentance11.lower()
print(sentance11)
# Out:
# check this link: https://example.com

# %% [markdown]
# ### Q12: AI, ML, NLP — ALL ARE IMPORTANT FIELDS!

# %%
sentance12 = 'AI, ML, NLP — ALL ARE IMPORTANT FIELDS!'

lowercase12 = sentance12.lower()
print(lowercase12)
# Out:
# ai, ml, nlp — all are important fields!

# %% [markdown]
# # Coding Practice Task

# %% [markdown]
# ### Q13: Given List
# list convert lowercase using loop

# %%
given_list = ["HELLO", "WORLD", "PYTHON NLP"]

lower = [word.lower() for word in given_list if word.lower() not in given_list]
print(lower)
# Out:
# ['hello', 'world', 'python nlp']

# %% [markdown]
# ### Q14: User se input lo aur usay lowercase mein convert karo

# %%
text_from_user = input('Enter your text..')

user_input_to_lowercase = text_from_user.lower()

print(text_from_user)
print(user_input_to_lowercase)
# Out:
# I SPECIALIZED In NLP.
# i specialized in nlp.

# %% [markdown]
# ### Q15: (🔥 Important)
#
# #### Required paragraph:
#
# 1. Corpus Convert To Lowercase
#
# 2. Apply Tokennization

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize

df = pd.read_csv(r'C:\Users\Muhammad Yahya\Downloads\python\NLP\Text_Preprocessing\IMDB Dataset.csv.zip')

corpus = df['review'][0]

corpus_convert_lowercase = corpus.lower()

sentance_tokenize = sent_tokenize(corpus_convert_lowercase)

print(f'{corpus}\n')
print(sentance_tokenize)
# Out:
# One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the f
# ...
