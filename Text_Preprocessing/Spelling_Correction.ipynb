# %% [markdown]
# # Spelling Correction

# %%
from textblob import TextBlob

# %%
incorrect_text = "I Loove Natural Languag Procesing"

txtblob = TextBlob(incorrect_text)
txtblob.correct().string
# Out:
# 'I Love Natural Language Processing'
