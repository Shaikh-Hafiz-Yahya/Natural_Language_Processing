# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Download stopwords if you haven't already
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Muhammad
# [nltk_data]     Yahya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Muhammad
# [nltk_data]     Yahya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_stop_words(text):    

# Tokenize the input text   
    words = word_tokenize(text)       
# Get the set of English stop words   
    stop_words = set(stopwords.words('english'))      
# Remove stop words from the tokenized words  
    filtered_words = [word for word in words if word.lower() not in stop_words]      
    return ' '.join(filtered_words)

usageinput_text = "I am learning Natural Language Processing and it is quite interesting."
filtered_text = remove_stop_words(usageinput_text)

print("Original text:", usageinput_text)
print("Filtered text:", filtered_text)
# Out:
# Original text: I am learning Natural Language Processing and it is quite interesting.
# Filtered text: learning Natural Language Processing quite interesting .
