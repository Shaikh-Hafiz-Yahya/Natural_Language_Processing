# %% [markdown]
# # BOW TECHNIQUE

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.tokenize import word_tokenize

# %%
# sentance 
sentance = "The laptop works great and has excellent bettery life"

# %%
word_tok = word_tokenize(sentance)
word_tok
# Out:
# ['The',
#  'laptop',
#  'works',
#  'great',
#  'and',
#  'has',
#  'excellent',
#  'bettery',
#  'life']
